# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_minusone = pd.read_csv("prices_round_2_day_-1.csv", delimiter=';')

# %%
day_minusone.columns
# Out:
# Index(['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1',
#        'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
#        'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
#        'ask_price_3', 'ask_volume_3', 'mid_price', 'profit_and_loss'],
#       dtype='object')

# %%
day_minusone.drop(["day", "profit_and_loss"], axis=1)
# Out:
#        timestamp       product  bid_price_1  bid_volume_1  bid_price_2  \
# 0              0        PEARLS        10002             1       9996.0
# 1              0  PINA_COLADAS        14999            38      14998.0
# 2              0      COCONUTS         7999           162          NaN
# 3              0       BANANAS         4951             1       4946.0
# 4            100        PEARLS         9996             2       9995.0
# ...          ...           ...          ...           ...          ...
# 39995     999800        PEARLS         9995            20          NaN
# 39996     999900  PINA_COLADAS        15228           102          NaN
# 39997     999900      COCONUTS         8113           178          NaN
# 39998     999900       BANANAS         4892            31          NaN
# 39999     999900        PEARLS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
coconuts = day_minusone[day_minusone["product"] == "COCONUTS"]

# %%
coconuts["SMA100"] = coconuts["mid_price"].rolling(20).mean()
plt.figure(figsize=(30,18))
plt.plot(coconuts["timestamp"], coconuts["mid_price"])
plt.plot(coconuts["timestamp"], coconuts["SMA100"], color="red")
plt.show()
# Out:
# /var/folders/ys/76yn_3qx7g33rlx42fjhwkpr0000gn/T/ipykernel_35949/854921063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coconuts["SMA100"] = coconuts["mid_price"].rolling(20).mean()

# %%
pina = day_minusone[day_minusone["product"] == "PINA_COLADAS"]

# %%
pina["SMA100"] = pina["mid_price"].rolling(20).mean()
plt.figure(figsize=(30,18))
plt.plot(pina["timestamp"], pina["mid_price"])
plt.plot(pina["timestamp"], pina["SMA100"], color="red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 10000, 1000/3
s = np.random.normal(mu, sigma, 1000)

# Create the bins and histogram
plt.figure(figsize=(30,18))
count, bins, ignored = plt.hist(s, 20)
plt.show()

# %%
s = np.sort(s)
print(s)
# Out:
# [ 9011.25538003  9075.98370627  9077.53126155  9082.31512717
#   9109.21517143  9187.11166734  9196.60949162  9207.15615832
#   9227.26040686  9229.19229615  9234.81560653  9242.94494089
#   9279.47438812  9296.86306451  9297.63297792  9326.39259002
#   9329.96301084  9330.53221606  9337.65149065  9343.3820539
#   9348.91336508  9355.60693458  9360.57368723  9363.35919659
#   9371.99929926  9387.60911746  9391.01781915  9397.38636781
#   9397.55189485  9402.87989956  9404.06578519  9405.24651135
#   9411.59174644  9412.44043271  9414.15554892  9415.30518181
#   9415.61208997  9421.3962931   9422.29504238  9423.87623382
#   9431.61495577  9439.2644641   9439.31378531  9440.15611883
#   9440.54983195  9444.71634467  9452.15367524  9452.26365546
#   9454.74234155  9454.84567271  9456.48687558  9458.12341817
#   9468.64468694  9470.78034239  9471.56075965  9473.60702271
#   9478.4948189   9480.1355119   9482.36098081  9484.13971633
# ...

# %%
bottom_25 = s[:500]

# %%
print(np.mean(bottom_25))
# Out:
# 9747.419692346193
